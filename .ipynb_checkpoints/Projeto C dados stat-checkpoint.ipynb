# %%
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import seaborn as sns

# %%
data1= pd.read_excel('Tweets.xlsx',sheet_name=0)
Re1= data1.Treinamento[data1.Controle == 1]
Irr1=data1.Treinamento[data1.Controle == 0]
print(Re1)
print(Irr1)
# Out:
# 0      toyota corolla touring sports é a perua substi...
# 6                        um corolla não é uma ma ideia 😋
# 8        carai, to de carona num corolla, que carro foda
# 20     @autossegredos o corolla tem bons concorrentes...
# 27     rt @uolcarros: sim, existe uma nova geração da...
# 39     adeus auris. toyota volta atrás e recupera cor...
# 43     vw virtus vende mais que o corolla no começo d...
# 44     @_rodrigoap já peguei um uber q o carro era um...
# 45                        só esse corolla na minha vida.
# 49     é pré requisito se aposentar, comprar um corol...
# 51                     @luznocaus bora pega o corolla ai
# 53     toyota revela carrinha do novo corolla https:/...
# 55     falar q é corolla é fácil\nquero ver ter a pot...
# 59     @wyllikscarvalho kkkkkk fé no pai que o coroll...
# 66     adeus, auris! toyota volta a chamar hatch de c...
# 74     @mileyprodigy hahahahahahahahahaa ainda não, m...
# ...

# %%
def Limpar(frases):
    strings=[]
    for i in frases:
        i.replace('/n','')
        i.replace('!','')
        i.replace("'","")
        junto= i.split(" ")
        for w in junto:
            if '@' in w:
                del w
            elif 'http' in w:
                del w
            elif w == 'rt':
                  del w
            elif '\n' in w:
                del w
            else:
                x = list(w)
                for p in x:
                    if p == '?':
                        x.remove(p)
                    elif p == ',':
                        x.remove(p)
                    elif p == '.':
                        x.remove(p)
                    elif p == '!':
                        x.remove(p)
                    elif p == '#':
                        x.remove(p)
                    elif p == '&':
                        x.remove(p)
                    elif p == ';':
                        x.remove(p)
                    elif p == '(':
                        x.remove(p)
                    elif p == ')':
                        x.remove(p)
                    elif p == '"':
                        x.remove(p)
                    elif p == '/':
                        x.remove(p)
                    elif p == '*':
                        x.remove(p)
                    elif p == '-':
                        x.remove(p)
                tudo= ''.join(x)
                strings.append(tudo)
    return strings

# %%
relevante=Limpar(Re1)
Fundamental1=pd.Series(relevante)
Probabilidade_fundamental1=dict(Fundamental1.value_counts(normalize=True))

irrelevante=Limpar(Irr1)
Descartavel1=pd.Series(irrelevante)
Probabilidade_descartavel1=dict(Descartavel1.value_counts(normalize=True))

# %%
print(Fundamental1)
# Out:
# 0           toyota
# 1          corolla
# 2          touring
# 3           sports
# 4                é
# 5                a
# 6            perua
# 7       substituta
# 8               da
# 9          fielder
# 10              um
# 11         corolla
# 12             não
# 13               é
# 14             uma
# 15              ma
# 16           ideia
# 17               😋
# 18           carai
# 19              to
# 20              de
# 21          carona
# 22             num
# 23         corolla
# 24             que
# 25           carro
# 26            foda
# 27               o
# 28         corolla
# 29             tem
#           ...
# 465              o
# 466         sentra
# 467            não
# 468          deixa
# 469              a
# 470        desejar
# 471             eh
# 472              q
# 473        corolla
# 474          carro
# 475             de
# 476           veio
# 477          broxa
# 478           nova
# 479        corolla
# 480       carrinha
# ...

# %%
print(Descartavel1)
# Out:
# 0             tinha
# 1                um
# 2           corolla
# 3             preto
# 4               bem
# 5                na
# 6            frente
# 7                da
# 8             minha
# 9              casa
# 10                e
# 11            tinha
# 12               um
# 13            homem
# 14           dentro
# 15          tirando
# 16             foto
# 17               da
# 18            minha
# 19             casa
# 20           depois
# 21              que
# 22           acendi
# 23                a
# 24              luz
# 25               da
# 26          varanda
# 27              ele
# 28              foi
# 29           embora
#            ...
# 4345        corolla
# 4346            xei
# 4347            aut
# 4348
# 4349           2006
# 4350
# 4351          volta
# 4352      redondarj
# 4353
# 4354    ref:1786521
# 4355
# 4356             r$
# 4357       2790000:
# 4358          vendo
# 4359          carro
# 4360          usado
# 4361         toyota
# ...

# %%
print(Probabilidade_fundamental1)
# Out:
# {'corolla': 0.09494949494949495, 'o': 0.04040404040404041, 'de': 0.03636363636363636, 'é': 0.03232323232323232, 'um': 0.030303030303030304, 'a': 0.020202020202020204, 'toyota': 0.01818181818181818, 'carro': 0.01818181818181818, 'que': 0.01616161616161616, 'e': 0.014141414141414142, 'do': 0.012121212121212121, 'q': 0.012121212121212121, 'não': 0.010101010101010102, 'da': 0.010101010101010102, 'sports': 0.010101010101010102, 'touring': 0.010101010101010102, 'em': 0.010101010101010102, 'meu': 0.00808080808080808, 'mas': 0.00808080808080808, 'eu': 0.00808080808080808, 'no': 0.00808080808080808, 'só': 0.00808080808080808, 'perua': 0.00808080808080808, 'quando': 0.006060606060606061, 'já': 0.006060606060606061, '': 0.006060606060606061, 'ter': 0.006060606060606061, 'era': 0.006060606060606061, 'se': 0.006060606060606061, 'gosto': 0.006060606060606061, 'auris': 0.00404040404040404, 'esse': 0.00404040404040404, 'ficar': 0.00404040404040404, 'volta': 0.00404040404040404, 'uns': 0.004040404040
# ...

# %%
print(Probabilidade_descartavel1)
# Out:
# {'um': 0.05028571428571429, 'corolla': 0.04982857142857143, 'que': 0.04617142857142857, 'de': 0.032, 'e': 0.028114285714285713, 'a': 0.018285714285714287, '': 0.015085714285714286, 'o': 0.0144, 'cara': 0.0128, 'agora': 0.012342857142857143, 'namora': 0.012114285714285715, 'dirige': 0.012114285714285715, 'blazer': 0.011885714285714286, 'usa': 0.011885714285714286, 'do': 0.0112, 'fala': 0.010971428571428571, 'é': 0.010514285714285714, 'da': 0.008685714285714286, 'vídeo': 0.008685714285714286, 'eu': 0.008228571428571429, 'com': 0.007542857142857143, 'na': 0.0070857142857142855, 'gostei': 0.006857142857142857, 'em': 0.006628571428571429, 'uma': 0.006628571428571429, 'no': 0.006171428571428572, 'não': 0.005942857142857143, 'toyota': 0.005485714285714286, 'só': 0.005485714285714286, 'carro': 0.005028571428571428, 'me': 0.0048, 'tem': 0.004571428571428572, 'mais': 0.004342857142857143, 'q': 0.004114285714285714, 'pra': 0.0038857142857142857, 'se': 0.0038857142857142857, 'ao': 0.003885714285
# ...

# %%
####Até aqui 100% certo

# %%
data2= pd.read_excel('Tweets.xlsx',sheet_name=1)
Re2= data2.Teste[data2.Controle == 1]
Irr2=data2.Teste[data2.Controle == 0]
print(Re2)
print(Irr2)
# Out:
# 16     coisa linda! toyota do brasil, por favor, vend...
# 20     @veja com esse valor vai disputar com o toyota...
# 22     convencer ela a não compra o corolla e pegar o...
# 27     em 2017, o toyota corolla ganhou frente nova n...
# 34     toyota corolla: depois do hatch, é a vez da pe...
# 36     @caroisandiego todo a serenidade de quem sabe ...
# 38        tropa do corolla é uma  sucessagem  da nada 😂😂
# 39     mandaram avisar que os primo leão tão de corol...
# 43                   @justbfr corolla melhor que civic 🙊
# 48     uma meta? — minha casa, meu corolla https://t....
# 61     novo corolla 2020 chega ao brasil até julho do...
# 64     corolla falhando https://t.co/3caxkjikhw via @...
# 75     coloquei 100 reais de álcool dia 24 e durou at...
# 86     diesel de fora: nova toyota corolla touring sp...
# 91     a história do toyota corolla\nhttps://t.co/qyk...
# 95     o corolla é principalmente reconhecido pela su...
# ...

# %%
####Avaliar Tweets Teste
####Classificador
escolha=int(input("Insira uma linha para ser analisada:"))
frase=data2.iloc[escolha,0]
word=str(frase).split(" ")
analise=Limpar(word)

Ptr=1
Ptirr=1


for i in analise:
    if i in Probabilidade_fundamental1:
        Ptr = Ptr*Probabilidade_fundamental1[i]
    else:
        Ptr = Ptr *1
print(Ptr)
for i in analise:
    if i in Probabilidade_descartavel1:
        Ptirr = Ptirr * Probabilidade_descartavel1[i]
    else:
        Ptirr = Ptirr * 1

        
print(Ptirr)
print(frase)



if Ptr > Ptirr:
    print("Relevante")
else:
    print("Irrelevante")
# Out:
# Insira uma linha para ser analisada:45
# 5.888599991754763e-12
# 5.539817163005741e-25
# manhumirim
# corolla sai da pista, tomba e bate em uno estacionado
# https://t.co/ods1qew8lp — in manhuaçu, mg https://t.co/1prrpo3rim
# RELEVANTE

# %%
Falsopositivo=0
Falsonegativo=0
Verdadepositivo=0
Verdadenegativo=0
 
    
for i in range(len(data2)):
    if data2[i] == data1[i] and data2[i] == 'Relevante':
        Verdadepositivo+=1
   
        
        
        
print(Verdadepositivo)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-a9c766f5653b> in <module>()
#       6
#       7 for i in range(len(data2)):
# ...
